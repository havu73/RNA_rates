# %%
from plots import plot_estElong_results as plot
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import importlib
importlib.reload(plot)
estElong_folder = '/gladstone/engelhardt/lab/hvu/source/RNA_rates/splicingrates/simulations/results/without_PBD/no_fragment_read_filter/oneMinLabel/'
output_prefix = '/gladstone/engelhardt/lab/hvu/source/RNA_rates/splicingrates/simulations/results/without_PBD/no_fragment_read_filter/oneMinLabel'
df = plot.get_result_df(estElong_folder)
no_long_gene_df = df[df['too_long']==False]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 9
#       7 estElong_folder = '/gladstone/engelhardt/lab/hvu/source/RNA_rates/splicingrates/simulations/results/without_PBD/no_fragment_read_filter/oneMinLabel/'
#       8 output_prefix = '/gladstone/engelhardt/lab/hvu/source/RNA_rates/splicingrates/simulations/results/without_PBD/no_fragment_read_filter/oneMinLabel'
# ----> 9 df = plot.get_result_df(estElong_folder)
#      10 no_long_gene_df = df[df['too_long']==False]
#
# File ~/source/RNA_rates/splicingrates/simulations/plots/plot_estElong_results.py:32, in get_result_df(estElong_folder, filter_pred_h)
#      30 # read all the csv files into one df
#      31 df_list = list(map(read_one_csv, csv_files))
# ---> 32 df = pd.concat(df_list, ignore_index = True)
#      33 # filter plot_df such that estimated elongation rate is calculated successfully
# ...

# %%
importlib.reload(plot)
plot.plot_all_elongation(df, output_prefix)
plot.plot_length_stratified(df, output_prefix)
# Out:
# After filtering out pred_h with extremely large values (>=10), df.shape:  (972, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 importlib.reload(plot)
#       2 plot.plot_all_elongation(df, output_prefix)
# ----> 3 plot.plot_length_stratified(df, output_prefix)
#
# File ~/source/RNA_rates/splicingrates/simulations/plots/plot_estElong_results.py:130, in plot_length_stratified(df, output_prefix)
#     128 plot_df = df[df['length'] == length]
#     129 ax = fig[i][j]
# --> 130 sns.boxplot(plot_df, x='true_h', y='pred_h', ax=ax)
#     131 id_x = np.sort(plot_df['true_h'].unique())
#     132 numeric_mapping = {val: idx for idx, val in enumerate(id_x)}
#
# ...

# %%
# now I let's try to plot the elongation rate stratified both by length and by the Udist
importlib.reload(plot)
for idx in range(4):
    plot.length_Udist_stratified(df, output_prefix=output_prefix, length_tier_idx=idx)

# note that we will see a bunch of 'No data for Udist=,,,length=,,,'
# that can be caused by multple reason, but the most prominent one is that the length of the last exon is fixed as 5k while the length of the other exons are not fixed.

# %%
# Cases that pred_h is inf

# %%
import plot_estInit_results as plot
import importlib
importlib.reload(plot)
estInit_folder = 'init_est/without_PBD/'
df = plot.get_result_df(estInit_folder)
# plot the scatter plot of true_init and pred_init from df
import matplotlib.pyplot as plt
plt.scatter(df['true_init'], df['pred_init'])
# print the correlation between true and pred initiation rate
print('Correlation (true, pred):', np.corrcoef(df['true_init'], df['pred_init']))
plt.xlabel('True initiation rate')
plt.ylabel('Predicted initiation rate')
plt.title('Iniitation rate prediction')
plt.show()
plt.savefig(estInit_folder+'all_init_scatter.png')
# Out:
# init_est/without_PBD/
# Correlation (true, pred): [[1.         0.99472815]
#  [0.99472815 1.        ]]

# %%
list(range(5,20,5)) + list(range(20, 50, 10))
# Out:
# [5, 10, 15, 20, 30, 40]
